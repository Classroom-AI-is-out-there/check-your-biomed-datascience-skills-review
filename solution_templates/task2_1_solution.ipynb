# %% [markdown]
# # Task 2.1 solution scaffold
#
# Objective: build a classification model and predict held-out examples.
#
# - Training: `dataset/task2_1/train.csv`
# - Test features: `dataset/task2_1/test_features.csv`
# - Columns: `heartbeat_id`, `prediction`

# %% [markdown]
# ## 1. Imports and random seed

# %%
# TODO: add the libraries your approach needs
import numpy as np
import pandas as pd
from biomed_submission import get_output_path

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## 2. Load data

# %%
# TODO: load the training data from dataset/task2_1/train.csv
# TODO: load test_features from dataset/task2_1/test_features.csv

# %% [markdown]
# ## 3. Inspect data

# %%
# TODO: inspect shapes, data types, missing values, and class balance (when applicable)

# %% [markdown]
# ## 4. Preprocessing

# %%
# TODO: fit preprocessing on training data and transform test features consistently

# %% [markdown]
# ## 5. Training/validation split

# %%
# TODO: make a reproducible validation split when appropriate (do not use held-out grading labels)

# %% [markdown]
# ## 6. Construct and train model

# %%
# TODO: construct your classifier or clustering model
# TODO: train/fit it

# %% [markdown]
# ## 7. Validation metrics

# %%
# TODO: calculate and explain a suitable validation metric

# %% [markdown]
# ## 8. Held-out prediction

# %%
# TODO: create predicted_labels with exactly one scalar prediction per test example
# predicted_labels = ...

# %% [markdown]
# ## 9. Construct and save output
#
# This model-independent pattern is complete, but it needs your `test_features` and `predicted_labels`. `index=False` prevents an unwanted Pandas index column.

# %%
# TODO: if your input format is NPZ/TXT/FASTA, create test_ids from its ID field/records.
# For CSV, this is usually: test_ids = test_features['heartbeat_id']
submission = pd.DataFrame({'heartbeat_id': test_ids, 'prediction': predicted_labels})
output_path = get_output_path('task2_1')
submission.to_csv(output_path, index=False)

# %% [markdown]
# ## 10. Verify the artifact

# %%
print('Output path:', output_path)
print('Columns:', submission.columns.tolist())
print('Rows:', len(submission))
print('Missing values:', int(submission.isna().sum().sum()))
print(submission.head())
